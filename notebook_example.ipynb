# %% [markdown]
# # 📓 Jupyter Notebook — Feature Showcase
#
# This notebook demonstrates the core capabilities of Jupyter: **code execution**, **functions**, **plots**, **markdown**, **widgets**, and **data analysis**.
#
# ---

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
import pandas as pd
from IPython.display import display

# Optional: nicer plots
plt.rcParams.update({
    'figure.dpi': 120,
    'axes.spines.top': False,
    'axes.spines.right': False,
    'axes.grid': True,
    'grid.alpha': 0.3,
})

print('All imports successful ✓')
# Out:
# All imports successful ✓

# %% [markdown]
# ---
# ## 2. Variables, Expressions & Print Formatting

# %%
# Basic variables and f-string formatting
name    = 'André'
pi      = np.pi
e       = np.e
phi     = (1 + np.sqrt(5)) / 2  # golden ratio

print(f'Hello, {name}!')
print(f'  π  = {pi:.6f}')
print(f'  e  = {e:.6f}')
print(f'  φ  = {phi:.6f}  (golden ratio)')

# Last expression is auto-displayed
np.array([pi, e, phi])
# Out:
# Hello, André!
#   π  = 3.141593
#   e  = 2.718282
#   φ  = 1.618034  (golden ratio)
# array([3.14159265, 2.71828183, 1.61803399])

# %% [markdown]
# ---
# ## 3. Functions & Docstrings

# %%
def sigmoid(x):
    """Logistic sigmoid function: σ(x) = 1 / (1 + e^-x)"""
    return 1 / (1 + np.exp(-x))

def relu(x):
    """Rectified Linear Unit: max(0, x)"""
    return np.maximum(0, x)

def tanh_custom(x):
    """Hyperbolic tangent activation."""
    return np.tanh(x)

def stats_summary(arr):
    """Return a dict of basic statistics for a numpy array."""
    return {
        'mean':   np.mean(arr),
        'std':    np.std(arr),
        'min':    np.min(arr),
        'max':    np.max(arr),
        'median': np.median(arr),
    }

# Quick test
x_test = np.linspace(-3, 3, 7)
print('x       :', np.round(x_test, 2))
print('sigmoid :', np.round(sigmoid(x_test), 3))
print('relu    :', np.round(relu(x_test), 3))
# Out:
# x       : [-3. -2. -1.  0.  1.  2.  3.]
# sigmoid : [0.047 0.119 0.269 0.5   0.731 0.881 0.953]
# relu    : [0. 0. 0. 0. 1. 2. 3.]

# %% [markdown]
# ---
# ## 4. Plot — Activation Functions

# %%
x = np.linspace(-5, 5, 400)

fig, axes = plt.subplots(1, 3, figsize=(13, 4))
fig.suptitle('Activation Functions', fontsize=14, fontweight='bold', y=1.02)

pairs = [
    (sigmoid,      'Sigmoid σ(x)',  '#7c6af7'),
    (relu,         'ReLU',          '#f76a8a'),
    (tanh_custom,  'Tanh',          '#6af7c8'),
]

for ax, (fn, title, color) in zip(axes, pairs):
    y = fn(x)
    ax.plot(x, y, color=color, lw=2.5)
    ax.axhline(0, color='gray', lw=0.8, ls='--')
    ax.axvline(0, color='gray', lw=0.8, ls='--')
    ax.set_title(title, fontsize=12)
    ax.set_xlabel('x')

plt.tight_layout()
plt.show()

# %%
def sdadsa():
    """This function does nothing."""
    pass

# %% [markdown]
# ---
# ## 5. NumPy — Array Operations & Linear Algebra

# %%
# Matrix operations
A = np.array([[4, 3],
              [6, 3]], dtype=float)

eigenvalues, eigenvectors = np.linalg.eig(A)
det = np.linalg.det(A)
inv = np.linalg.inv(A)

print('Matrix A:')
print(A)
print(f'\nDeterminant : {det:.2f}')
print(f'Eigenvalues : {eigenvalues}')
print('\nInverse A⁻¹:')
print(np.round(inv, 4))
print('\nVerify A @ A⁻¹ = I:')
print(np.round(A @ inv, 6))
# Out:
# Matrix A:
# [[4. 3.]
#  [6. 3.]]
#
# Determinant : -6.00
# Eigenvalues : [ 7.77200187 -0.77200187]
#
# Inverse A⁻¹:
# [[-0.5     0.5   ]
#  [ 1.     -0.6667]]
#
# Verify A @ A⁻¹ = I:
# [[1. 0.]
#  [0. 1.]]

# %% [markdown]
# ---
# ## 6. Plot — Signal Analysis (FFT)

# %%
# Compose a signal with known frequencies
fs   = 1000          # sampling rate [Hz]
t    = np.arange(0, 1, 1/fs)
f1, f2, f3 = 5, 50, 120  # Hz

signal = (1.0 * np.sin(2*np.pi*f1*t) +
          0.5 * np.sin(2*np.pi*f2*t) +
          0.3 * np.sin(2*np.pi*f3*t) +
          0.2 * np.random.randn(len(t)))   # add noise

# FFT
N     = len(signal)
freqs = np.fft.rfftfreq(N, 1/fs)
amps  = np.abs(np.fft.rfft(signal)) * 2 / N

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 6))
fig.suptitle('Signal Analysis via FFT', fontsize=13, fontweight='bold')

# Time domain
ax1.plot(t[:300], signal[:300], color='#7c6af7', lw=1)
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('Amplitude')
ax1.set_title('Time domain (first 0.3 s)')

# Frequency domain
ax2.plot(freqs, amps, color='#f76a8a', lw=1.5)
for f, label in zip([f1, f2, f3], ['5 Hz', '50 Hz', '120 Hz']):
    ax2.axvline(f, color='#6af7c8', lw=1, ls='--', alpha=0.7)
    ax2.text(f+1, amps.max()*0.8, label, fontsize=9, color='#6af7c8')
ax2.set_xlim(0, 200)
ax2.set_xlabel('Frequency [Hz]')
ax2.set_ylabel('|X(f)|')
ax2.set_title('Frequency spectrum')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 7. Pandas — DataFrames & Statistics

# %%
np.random.seed(42)
n = 200

df = pd.DataFrame({
    'temperature': np.random.normal(25, 5, n),          # °C
    'pressure':    np.random.normal(101325, 500, n),    # Pa
    'velocity':    np.abs(np.random.normal(50, 15, n)), # m/s
    'label':       np.random.choice(['A', 'B', 'C'], n)
})

# Derived column
df['mach'] = df['velocity'] / 343.0  # approximate, sea level

print(f'Shape: {df.shape}')
display(df.head(8))
print('\nDescriptive statistics:')
display(df.describe().round(2))
# Out:
# Shape: (200, 5)
#    temperature       pressure   velocity label      mach
# 0    27.483571  101503.893680  26.083585     C  0.076045
# 1    24.308678  101605.392263  41.009375     A  0.119561
# 2    28.238443  101866.525622  50.078655     B  0.146002
# 3    32.615149  101851.901026  50.704709     C  0.147827
# 4    23.829233  100636.165316  43.249018     C  0.126090
# 5    23.829315  100856.087480  59.342749     C  0.173011
# 6    32.896064  101582.517634  33.985694     C  0.099084
# 7    28.837174  101581.892975  47.864308     B  0.139546
# Descriptive statistics:
#        temperature   pressure  velocity    mach
# count       200.00     200.00    200.00  200.00
# mean         24.80  101367.93     48.72    0.14
# std           4.66     493.50     14.91    0.04
# min          11.90   99704.37     12.93    0.04
# 25%          21.47  101022.08     38.09    0.11
# 50%          24.98  101364.42     48.84    0.14
# 75%          27.50  101668.62     58.58    0.17
# ...

# %% [markdown]
# ---
# ## 8. Plot — DataFrame Visualisation

# %%
fig = plt.figure(figsize=(13, 9))
gs  = gridspec.GridSpec(2, 3, figure=fig, hspace=0.45, wspace=0.35)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[1, :])

colors = {'A': '#7c6af7', 'B': '#f76a8a', 'C': '#6af7c8'}

# Scatter: temperature vs velocity
for label, grp in df.groupby('label'):
    ax1.scatter(grp['temperature'], grp['velocity'],
                c=colors[label], alpha=0.5, s=18, label=label)
ax1.set_xlabel('Temperature [°C]')
ax1.set_ylabel('Velocity [m/s]')
ax1.set_title('Temp vs Velocity')
ax1.legend(title='Label', fontsize=8)

# Histogram: mach number
ax2.hist(df['mach'], bins=25, color='#f7c46a', edgecolor='none', alpha=0.85)
ax2.set_xlabel('Mach number')
ax2.set_ylabel('Count')
ax2.set_title('Mach Distribution')

# Box plot per label
data_box = [df[df['label']==l]['velocity'].values for l in ['A','B','C']]
bp = ax3.boxplot(data_box, patch_artist=True,
                 boxprops=dict(linewidth=1.2),
                 medianprops=dict(color='white', lw=2))
for patch, color in zip(bp['boxes'], colors.values()):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)
ax3.set_xticklabels(['A', 'B', 'C'])
ax3.set_ylabel('Velocity [m/s]')
ax3.set_title('Velocity by Label')

# Rolling mean of temperature
ax4.plot(df.index, df['temperature'], color='gray', lw=0.7, alpha=0.5, label='Raw')
ax4.plot(df.index, df['temperature'].rolling(10).mean(),
         color='#7c6af7', lw=2, label='Rolling mean (n=10)')
ax4.set_xlabel('Sample index')
ax4.set_ylabel('Temperature [°C]')
ax4.set_title('Temperature — Raw vs Rolling Mean')
ax4.legend(fontsize=9)

fig.suptitle('DataFrame Visualisation', fontsize=14, fontweight='bold', y=1.01)
plt.show()

# %% [markdown]
# ---
# ## 9. Plot — 3-D Surface

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa

x3 = np.linspace(-4, 4, 80)
y3 = np.linspace(-4, 4, 80)
X, Y = np.meshgrid(x3, y3)
R = np.sqrt(X**2 + Y**2) + 1e-9
Z = np.sin(R) / R   # sinc-like surface

fig = plt.figure(figsize=(9, 6))
ax  = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='plasma',
                       linewidth=0, antialiased=True, alpha=0.9)
fig.colorbar(surf, ax=ax, shrink=0.5, label='z = sin(r)/r')
ax.set_title('3-D Surface: sin(r)/r', fontsize=13)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 10. Interactive Widgets (`ipywidgets`)

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive

@interact(frequency=(1, 20, 0.5), amplitude=(0.1, 3.0, 0.1),
          phase=(0.0, 2*np.pi, 0.1), noise=(0.0, 1.0, 0.05))
def plot_wave(frequency=5, amplitude=1.0, phase=0.0, noise=0.0):
    """Interactive sine wave with noise."""
    t  = np.linspace(0, 1, 500)
    y  = amplitude * np.sin(2*np.pi*frequency*t + phase)
    y += noise * np.random.randn(len(t))

    fig, ax = plt.subplots(figsize=(10, 3.5))
    ax.plot(t, y, color='#7c6af7', lw=1.8)
    ax.set_xlim(0, 1)
    ax.set_xlabel('Time [s]')
    ax.set_ylabel('Amplitude')
    ax.set_title(f'f={frequency} Hz  |  A={amplitude}  |  φ={phase:.2f} rad  |  noise={noise}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ---
# ## 11. Error Handling & Assertions

# %%
def safe_divide(a, b):
    """Divide a by b with a ZeroDivisionError guard."""
    if b == 0:
        raise ZeroDivisionError('Denominator cannot be zero.')
    return a / b

# Normal case
print(safe_divide(10, 3))

# Handled exception
try:
    result = safe_divide(10, 0)
except ZeroDivisionError as err:
    print(f'Caught: {err}')

# Assertions
assert sigmoid(0) == 0.5,    'sigmoid(0) must be 0.5'
assert relu(-5)   == 0,      'relu of negative must be 0'
assert relu(3)    == 3,      'relu of positive must be identity'
print('All assertions passed ✓')

# %% [markdown]
# ---
# ## 12. Magic Commands

# %%
# %timeit — benchmark a cell expression
# %timeit np.dot(np.random.randn(500), np.random.randn(500))

# %%
# %%time — time the entire cell
# %%time
M = np.random.randn(1000, 1000)
_ = np.linalg.svd(M, full_matrices=False)

# %%
# %who — list variables in namespace
# %who

# %% [markdown]
# ---
# ## 13. Shell Commands

# %%
# Run shell commands directly with !
# !echo "Python version:"
# !python --version
# !pip show numpy | grep -E 'Name|Version'

# %% [markdown]
# ---
# ## 14. Putting It Together — Mini Analysis Pipeline

# %%
def generate_data(n=300, seed=0):
    """Generate synthetic dataset with two Gaussian clusters."""
    rng = np.random.default_rng(seed)
    X1 = rng.multivariate_normal([2, 2],  [[1, 0.5],[0.5, 1]], n//2)
    X2 = rng.multivariate_normal([-2,-2], [[1,-0.4],[-0.4,1]], n//2)
    X  = np.vstack([X1, X2])
    y  = np.array([0]*(n//2) + [1]*(n//2))
    return X, y

def decision_boundary(X, y, ax, title=''):
    """Plot data points and a simple linear boundary."""
    c = ['#7c6af7' if yi==0 else '#f76a8a' for yi in y]
    ax.scatter(X[:,0], X[:,1], c=c, alpha=0.6, s=20, edgecolors='none')
    # Fit a simple threshold on the first PCA direction (manual)
    mean_diff = X[y==0].mean(0) - X[y==1].mean(0)
    midpoint  = (X[y==0].mean(0) + X[y==1].mean(0)) / 2
    # Draw perpendicular boundary line
    if mean_diff[0] != 0:
        slope = mean_diff[1] / mean_diff[0]
        perp_slope = -1 / slope
        xs = np.array([X[:,0].min()-1, X[:,0].max()+1])
        ys = midpoint[1] + perp_slope * (xs - midpoint[0])
        ax.plot(xs, ys, 'w--', lw=1.5, label='Decision boundary')
        ax.legend(fontsize=8)
    ax.set_title(title)
    ax.set_xlabel('x₁'); ax.set_ylabel('x₂')

X, y = generate_data()
print(f'Dataset: {X.shape[0]} samples, {X.shape[1]} features')
print(f'Class balance: {np.bincount(y)}')
print(stats_summary(X[:,0]))

fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))
decision_boundary(X, y, axes[0], 'Full dataset')

# Add noise and re-plot
X_noisy = X + np.random.randn(*X.shape) * 0.8
decision_boundary(X_noisy, y, axes[1], 'With extra noise')

fig.suptitle('Mini Analysis Pipeline — Synthetic Clusters', fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## ✅ Summary
#
# | Feature | Cell(s) |
# |---|---|
# | Markdown (headings, tables, lists, math) | Throughout |
# | Imports & setup | 1 |
# | Variables & expressions | 2 |
# | Functions & docstrings | 3 |
# | Line/subplots | 4, 8 |
# | NumPy / linear algebra | 5 |
# | Signal analysis & FFT | 6 |
# | Pandas DataFrames | 7 |
# | 3-D surface plot | 9 |
# | Interactive widgets | 10 |
# | Error handling | 11 |
# | Magic commands | 12 |
# | Shell commands | 13 |
# | End-to-end pipeline | 14 |
